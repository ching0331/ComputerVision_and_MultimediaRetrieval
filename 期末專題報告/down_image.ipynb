# %% [markdown]
# # Unsplash

# %%
# 單一圖片

# 下載套件
import requests
from bs4 import BeautifulSoup
import os

# 使用 requests取得網頁內容
web = requests.get('https://unsplash.com/s/photos/night?license=free')

# 使用 beautifulsoup對取得的html內容進行解析
soup = BeautifulSoup(web.text, "html.parser")

# 取得image
img_url = soup.select('div[class~="d95fI"] div[class~="WxXog"] img')[0]["src"]
print(img_url)

下載圖片
img_file = requests.get(img_url)
f = open('Unsplash/night/0001.png', 'wb')
f.write(img_file.content)
f.close()
# Out:
# https://images.unsplash.com/photo-1505322022379-7c3353ee6291?q=80&w=1000&auto=format&fit=crop&ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxzZWFyY2h8MXx8bmlnaHR8ZW58MHx8MHx8fDI%3D

# %% [markdown]
# # day_night 圖片

# %%
# 下載套件
import requests
from bs4 import BeautifulSoup
import os

# 建立存放圖片的資料夾
os.makedirs('Unsplash/day_night', exist_ok=True)

# 儲存已下載圖片的 URL 集合
downloaded_images = set()

# day-sky 圖片
for i in range(18):
    index = str(i+1).zfill(4)
    # 使用 requests取得網頁內容
    web = requests.get('https://unsplash.com/s/photos/day-sky?license=free')
    # 使用 beautifulsoup對取得的html內容進行解析
    soup = BeautifulSoup(web.text, "html.parser")
    # 取得image_url
    img_url = soup.select('div[class~="d95fI"] div[class~="WxXog"] img')[i]["src"]
    
    # 檢查圖片是否已下載過
    if img_url in downloaded_images:
        continue

    # 下載圖片
    img_file = requests.get(img_url)
    f = open('Unsplash/day_night/{}.png'.format(index), 'wb')
    f.write(img_file.content)
    f.close()
    
    # 將圖片URL加入集合
    downloaded_images.add(img_url)

# %%
# 下載套件
import requests
from bs4 import BeautifulSoup
import os

# 儲存已下載圖片的 URL 集合
downloaded_images = set()

# night 圖片
for i in range(18):
    index = str(i+19).zfill(4)
    # 使用 requests取得網頁內容
    web = requests.get('https://unsplash.com/s/photos/night?license=free')
    # 使用 beautifulsoup對取得的html內容進行解析
    soup = BeautifulSoup(web.text, "html.parser")
    # 取得image_url
    img_url = soup.select('div[class~="d95fI"] div[class~="WxXog"] img')[i]["src"]
    
    # 檢查圖片是否已下載過
    if img_url in downloaded_images:
        continue
    
    # 下載圖片
    img_file = requests.get(img_url)
    f = open('Unsplash/day_night/{}.png'.format(index), 'wb')
    f.write(img_file.content)
    f.close()
    
    # 將圖片URL加入集合
    downloaded_images.add(img_url)

# %% [markdown]
# # sun_moon 圖片

# %%
# 下載套件
import requests
from bs4 import BeautifulSoup
import os

# 建立存放圖片的資料夾
os.makedirs('Unsplash/sun_moon', exist_ok=True)

# 儲存已下載圖片的 URL 集合
downloaded_images = set()

# sun 圖片
for i in range(18):
    index = str(i+1).zfill(4)
    # 使用 requests取得網頁內容
    web = requests.get('https://unsplash.com/s/photos/sun?license=free')
    # 使用 beautifulsoup對取得的html內容進行解析
    soup = BeautifulSoup(web.text, "html.parser")
    # 取得image_url
    img_url = soup.select('div[class~="d95fI"] div[class~="WxXog"] img')[i]["src"]
    
    # 檢查圖片是否已下載過
    if img_url in downloaded_images:
        continue
    
    # 下載圖片
    img_file = requests.get(img_url)
    f = open('Unsplash/sun_moon/{}.png'.format(index), 'wb')
    f.write(img_file.content)
    f.close()
    
    # 將圖片URL加入集合
    downloaded_images.add(img_url)

# %%
# 下載套件
import requests
from bs4 import BeautifulSoup
import os

# 儲存已下載圖片的 URL 集合
downloaded_images = set()

# moon 圖片
for i in range(18):
    index = str(i+19).zfill(4)
    # 使用 requests取得網頁內容
    web = requests.get('https://unsplash.com/s/photos/moon?license=free')
    # 使用 beautifulsoup對取得的html內容進行解析
    soup = BeautifulSoup(web.text, "html.parser")
    # 取得image_url
    img_url = soup.select('div[class~="d95fI"] div[class~="WxXog"] img')[i]["src"]
    
    # 檢查圖片是否已下載過
    if img_url in downloaded_images:
        continue
    
    # 下載圖片
    img_file = requests.get(img_url)
    f = open('Unsplash/sun_moon/{}.png'.format(index), 'wb')
    f.write(img_file.content)
    f.close()
    
    # 將圖片URL加入集合
    downloaded_images.add(img_url)

# %% [markdown]
# # suit_dress 圖片

# %%
# 下載套件
import requests
from bs4 import BeautifulSoup
import os

# 建立存放圖片的資料夾
os.makedirs('Unsplash/suit_dress', exist_ok=True)

# 儲存已下載圖片的 URL 集合
downloaded_images = set()

# Wedding-dress 圖片
for i in range(18):
    index = str(i+1).zfill(4)
    # 使用 requests取得網頁內容
    web = requests.get('https://unsplash.com/s/photos/Wedding-dress?license=free')
    # 使用 beautifulsoup對取得的html內容進行解析
    soup = BeautifulSoup(web.text, "html.parser")
    # 取得image_url
    img_url = soup.select('div[class~="d95fI"] div[class~="WxXog"] img')[i]["src"]
    
    # 檢查圖片是否已下載過
    if img_url in downloaded_images:
        continue
    
    # 下載圖片
    img_file = requests.get(img_url)
    f = open('Unsplash/suit_dress/{}.png'.format(index), 'wb')
    f.write(img_file.content)
    f.close()
    
    # 將圖片URL加入集合
    downloaded_images.add(img_url)

# %%
# 下載套件
import requests
from bs4 import BeautifulSoup
import os

# 儲存已下載圖片的 URL 集合
downloaded_images = set()

# suit 圖片
for i in range(18):
    index = str(i+19).zfill(4)
    # 使用 requests取得網頁內容
    web = requests.get('https://unsplash.com/s/photos/suit?license=free')
    # 使用 beautifulsoup對取得的html內容進行解析
    soup = BeautifulSoup(web.text, "html.parser")
    # 取得image_url
    img_url = soup.select('div[class~="d95fI"] div[class~="WxXog"] img')[i]["src"]
    
    # 檢查圖片是否已下載過
    if img_url in downloaded_images:
        continue
    
    # 下載圖片
    img_file = requests.get(img_url)
    f = open('Unsplash/suit_dress/{}.png'.format(index), 'wb')
    f.write(img_file.content)
    f.close()
    
    # 將圖片URL加入集合
    downloaded_images.add(img_url)

# %% [markdown]
# # ball 圖片

# %%
# 下載套件
import requests
from bs4 import BeautifulSoup
import os

# 建立存放圖片的資料夾
os.makedirs('Unsplash/ball', exist_ok=True)

# 儲存已下載圖片的 URL 集合
downloaded_images = set()

# tennis-ball 圖片
for i in range(9):
    index = str(i+1).zfill(4)
    # 使用 requests取得網頁內容
    web = requests.get('https://unsplash.com/s/photos/tennis-ball?license=free')
    # 使用 beautifulsoup對取得的html內容進行解析
    soup = BeautifulSoup(web.text, "html.parser")
    # 取得image_url
    img_url = soup.select('div[class~="d95fI"] div[class~="WxXog"] img')[i]["src"]

    # 檢查圖片是否已下載過
    if img_url in downloaded_images:
        continue
    
    # 下載圖片
    img_file = requests.get(img_url)
    f = open('Unsplash/ball/{}.png'.format(index), 'wb')
    f.write(img_file.content)
    f.close()
    
    # 將圖片URL加入集合
    downloaded_images.add(img_url)

# %%
# 下載套件
import requests
from bs4 import BeautifulSoup
import os

# 儲存已下載圖片的 URL 集合
downloaded_images = set()

# basketball-ball 圖片
for i in range(9):
    index = str(i+10).zfill(4)
    # 使用 requests取得網頁內容
    web = requests.get('https://unsplash.com/s/photos/basketball-ball?license=free')
    # 使用 beautifulsoup對取得的html內容進行解析
    soup = BeautifulSoup(web.text, "html.parser")
    # 取得image_url
    img_url = soup.select('div[class~="d95fI"] div[class~="WxXog"] img')[i]["src"]

    # 檢查圖片是否已下載過
    if img_url in downloaded_images:
        continue
    
    # 下載圖片
    img_file = requests.get(img_url)
    f = open('Unsplash/ball/{}.png'.format(index), 'wb')
    f.write(img_file.content)
    f.close()
    
    # 將圖片URL加入集合
    downloaded_images.add(img_url)

# %%
# 下載套件
import requests
from bs4 import BeautifulSoup
import os

# 儲存已下載圖片的 URL 集合
downloaded_images = set()

# badminton-ball 圖片
for i in range(9):
    index = str(i+19).zfill(4)
    # 使用 requests取得網頁內容
    web = requests.get('https://unsplash.com/s/photos/badminton-ball?license=free')
    # 使用 beautifulsoup對取得的html內容進行解析
    soup = BeautifulSoup(web.text, "html.parser")
    # 取得image_url
    img_url = soup.select('div[class~="d95fI"] div[class~="WxXog"] img')[i]["src"]

    # 檢查圖片是否已下載過
    if img_url in downloaded_images:
        continue
    
    # 下載圖片
    img_file = requests.get(img_url)
    f = open('Unsplash/ball/{}.png'.format(index), 'wb')
    f.write(img_file.content)
    f.close()
    
    # 將圖片URL加入集合
    downloaded_images.add(img_url)

# %%
# 下載套件
import requests
from bs4 import BeautifulSoup
import os

# 儲存已下載圖片的 URL 集合
downloaded_images = set()

# baseball 圖片
for i in range(9):
    index = str(i+28).zfill(4)
    # 使用 requests取得網頁內容
    web = requests.get('https://unsplash.com/s/photos/baseball?license=free')
    # 使用 beautifulsoup對取得的html內容進行解析
    soup = BeautifulSoup(web.text, "html.parser")
    # 取得image_url
    img_url = soup.select('div[class~="d95fI"] div[class~="WxXog"] img')[i]["src"]

    # 檢查圖片是否已下載過
    if img_url in downloaded_images:
        continue
    
    # 下載圖片
    img_file = requests.get(img_url)
    f = open('Unsplash/ball/{}.png'.format(index), 'wb')
    f.write(img_file.content)
    f.close()
    
    # 將圖片URL加入集合
    downloaded_images.add(img_url)

# %% [markdown]
# # 合併

# %%
# 下載套件
import requests
from bs4 import BeautifulSoup
import os

# 儲存已下載圖片的 URL 集合
downloaded_images = set()

# ---day_night 圖片-------------------------------------------

# 建立存放圖片的資料夾
os.makedirs('Unsplash/day_night', exist_ok=True)

for i in range(36):
    index = str(i+1).zfill(4)
    if i < 18:
        web = requests.get('https://unsplash.com/s/photos/day-sky?license=free') # 使用 requests取得網頁內容
        soup = BeautifulSoup(web.text, "html.parser") # 使用 beautifulsoup對取得的html內容進行解析
        img_url = soup.select('div[class~="d95fI"] div[class~="WxXog"] img')[i]["src"] # 取得image_url

        # 檢查圖片是否已下載過
        if img_url in downloaded_images:
            continue

        # 下載圖片
        img_file = requests.get(img_url)
        f = open('Unsplash/day_night/{}.png'.format(index), 'wb')
        f.write(img_file.content)
        f.close()

        downloaded_images.add(img_url) # 將圖片URL加入集合
    else:
        web = requests.get('https://unsplash.com/s/photos/night?license=free')
        soup = BeautifulSoup(web.text, "html.parser")
        img_url = soup.select('div[class~="d95fI"] div[class~="WxXog"] img')[i]["src"]

        if img_url in downloaded_images:
            continue

        img_file = requests.get(img_url)
        f = open('Unsplash/day_night/{}.png'.format(index), 'wb')
        f.write(img_file.content)
        f.close()

        downloaded_images.add(img_url)

# ---sun_moon 圖片-------------------------------------------

os.makedirs('Unsplash/sun_moon', exist_ok=True)

downloaded_images = set()

for i in range(36):
    index = str(i+1).zfill(4)
    if i < 18:
        web = requests.get('https://unsplash.com/s/photos/sun?license=free')
        soup = BeautifulSoup(web.text, "html.parser")
        img_url = soup.select('div[class~="d95fI"] div[class~="WxXog"] img')[i]["src"]

        if img_url in downloaded_images:
            continue

        img_file = requests.get(img_url)
        f = open('Unsplash/sun_moon/{}.png'.format(index), 'wb')
        f.write(img_file.content)
        f.close()

        downloaded_images.add(img_url)
    else:
        web = requests.get('https://unsplash.com/s/photos/moon?license=free')
        soup = BeautifulSoup(web.text, "html.parser")
        img_url = soup.select('div[class~="d95fI"] div[class~="WxXog"] img')[i]["src"]

        if img_url in downloaded_images:
            continue

        img_file = requests.get(img_url)
        f = open('Unsplash/sun_moon/{}.png'.format(index), 'wb')
        f.write(img_file.content)
        f.close()

        downloaded_images.add(img_url)

# ---ball 圖片-------------------------------------------

os.makedirs('Unsplash/ball', exist_ok=True)

for i in range(36):
    index = str(i+1).zfill(4)
    if i < 9:
        web = requests.get('https://unsplash.com/s/photos/tennis-ball?license=free')
        soup = BeautifulSoup(web.text, "html.parser")
        img_url = soup.select('div[class~="d95fI"] div[class~="WxXog"] img')[i]["src"]

        if img_url in downloaded_images:
            continue

        img_file = requests.get(img_url)
        f = open('Unsplash/ball/{}.png'.format(index), 'wb')
        f.write(img_file.content)
        f.close()

        downloaded_images.add(img_url)
    elif i < 18:
        web = requests.get('https://unsplash.com/s/photos/basketball-ball?license=free')
        soup = BeautifulSoup(web.text, "html.parser")
        img_url = soup.select('div[class~="d95fI"] div[class~="WxXog"] img')[i]["src"]

        if img_url in downloaded_images:
            continue

        img_file = requests.get(img_url)
        f = open('Unsplash/ball/{}.png'.format(index), 'wb')
        f.write(img_file.content)
        f.close()

        downloaded_images.add(img_url)
    elif i < 27:
        web = requests.get('https://unsplash.com/s/photos/badminton-ball?license=free')
        soup = BeautifulSoup(web.text, "html.parser")
        img_url = soup.select('div[class~="d95fI"] div[class~="WxXog"] img')[i]["src"]

        if img_url in downloaded_images:
            continue

        img_file = requests.get(img_url)
        f = open('Unsplash/ball/{}.png'.format(index), 'wb')
        f.write(img_file.content)
        f.close()

        downloaded_images.add(img_url)
    else:
        web = requests.get('https://unsplash.com/s/photos/baseball?license=free')
        soup = BeautifulSoup(web.text, "html.parser")
        img_url = soup.select('div[class~="d95fI"] div[class~="WxXog"] img')[i]["src"]

        if img_url in downloaded_images:
            continue

        img_file = requests.get(img_url)
        f = open('Unsplash/ball/{}.png'.format(index), 'wb')
        f.write(img_file.content)
        f.close()

        downloaded_images.add(img_url)

# ---suit_dress 圖片-------------------------------------------

os.makedirs('Unsplash/suit_dress', exist_ok=True)

downloaded_images = set()

for i in range(36):
    index = str(i+1).zfill(4)
    if i < 18:
        web = requests.get('https://unsplash.com/s/photos/Wedding-dress?license=free')
        soup = BeautifulSoup(web.text, "html.parser")
        img_url = soup.select('div[class~="d95fI"] div[class~="WxXog"] img')[i]["src"]
        
        # 檢查圖片是否已下載過
        if img_url in downloaded_images:
            continue

        img_file = requests.get(img_url)
        f = open('Unsplash/suit_dress/{}.png'.format(index), 'wb')
        f.write(img_file.content)
        f.close()

        downloaded_images.add(img_url)
    else:
        web = requests.get('https://unsplash.com/s/photos/suit?license=free')
        soup = BeautifulSoup(web.text, "html.parser")
        img_url = soup.select('div[class~="d95fI"] div[class~="WxXog"] img')[i]["src"]

        if img_url in downloaded_images:
            continue

        img_file = requests.get(img_url)
        f = open('Unsplash/suit_dress/{}.png'.format(index), 'wb')
        f.write(img_file.content)
        f.close()

        downloaded_images.add(img_url)

# %%
import os
import requests
from bs4 import BeautifulSoup

def download_images(url, start, end, folder, downloaded_images):
    web = requests.get(url) # 使用 requests取得網頁內容
    soup = BeautifulSoup(web.text, "html.parser") # 使用 beautifulsoup對取得的html內容進行解析
    for i in range(start, end):
        img_url = soup.select('div[class~="d95fI"] div[class~="WxXog"] img')[i]["src"] # 取得image_url
        
        if img_url in downloaded_images:
            continue
        
        # 下載圖片
        img_file = requests.get(img_url)
        with open(f'{folder}/{str(i+1).zfill(4)}.png', 'wb') as f:
            f.write(img_file.content)
        
        # 將圖片URL加入集合
        downloaded_images.add(img_url)


# 儲存已下載圖片的 URL 集合
downloaded_images = set()

os.makedirs('Unsplash/day_night', exist_ok=True)
download_images('https://unsplash.com/s/photos/day-sky?license=free', 0, 18, 'Unsplash/day_night', downloaded_images)
download_images('https://unsplash.com/s/photos/night?license=free', 18, 36, 'Unsplash/day_night', downloaded_images)

os.makedirs('Unsplash/sun_moon', exist_ok=True)
download_images('https://unsplash.com/s/photos/sun?license=free', 0, 18, 'Unsplash/sun_moon', downloaded_images)
download_images('https://unsplash.com/s/photos/moon?license=free', 18, 36, 'Unsplash/sun_moon', downloaded_images)

os.makedirs('Unsplash/ball', exist_ok=True)
download_images('https://unsplash.com/s/photos/tennis-ball?license=free', 0, 9, 'Unsplash/ball', downloaded_images)
download_images('https://unsplash.com/s/photos/basketball?license=free', 9, 18, 'Unsplash/ball', downloaded_images)
download_images('https://unsplash.com/s/photos/badminton-ball?license=free', 18, 27, 'Unsplash/ball', downloaded_images)
download_images('https://unsplash.com/s/photos/baseball?license=free', 27, 36, 'Unsplash/ball', downloaded_images)

os.makedirs('Unsplash/suit_dress', exist_ok=True)
download_images('https://unsplash.com/s/photos/Wedding-dress?license=free', 0, 18, 'Unsplash/suit_dress', downloaded_images)
download_images('https://unsplash.com/s/photos/suit?license=free', 18, 36, 'Unsplash/suit_dress', downloaded_images)
